# %%
import pymongo
import pandas as pd
import matplotlib

# %%
client = pymongo.MongoClient('127.0.0.1', 27017)
client
# Out:
# MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client['douban']
db
# Out:
# Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'douban')

# %%
db.authenticate('douban', 'chenxj123')
# Out:
# True

# %%
coll = db['book250']
coll
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'douban'), 'book250')

# %%
list(coll.find({}))
# Out:
# [{'_id': ObjectId('5c3fda8044bb8c3fd8716072'),
#   'book': '追风筝的人',
#   'author': '[美] 卡勒德·胡赛尼',
#   'time': '2006-5',
#   'price': 29.0,
#   'star': 8.9,
#   'mark_num': 382302},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716073'),
#   'book': '解忧杂货店',
#   'author': '[日] 东野圭吾',
#   'time': '2014-5',
#   'price': 39.5,
#   'star': 8.5,
#   'mark_num': 361830},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716074'),
#   'book': '小王子',
#   'author': '[法] 圣埃克苏佩里',
#   'time': '2003-8',
#   'price': 22.0,
#   'star': 9.0,
#   'mark_num': 304230},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716075'),
#   'book': '白夜行',
#   'author': '[日] 东野圭吾',
#   'time': '2008-9',
#   'price': 29.8,
#   'star': 9.1,
#   'mark_num': 266574},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716076'),
#   'book': '围城',
#   'author': '钱锺书',
#   'time': '1991-2',
#   'price': 19.0,
#   'star': 8.9,
#   'mark_num': 233079},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716077'),
#   'book': '三体',
#   'author': '刘慈欣',
#   'time': '2008-1',
#   'price': 23.0,
#   'star': 8.8,
#   'mark_num': 215648},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716078'),
#   'book': '嫌疑人X的献身',
#   'author': '[日] 东野圭吾',
#   'time': '2008-9',
#   'price': 28.0,
#   'star': 8.9,
#   'mark_num': 213803},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716079'),
#   'book': '挪威的森林',
#   'author': '[日] 村上春树',
#   'time': '2001-2',
#   'price': 18.8,
#   'star': 8.0,
#   'mark_num': 222166},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607a'),
#   'book': '百年孤独',
#   'author': '[哥伦比亚] 加西亚·马尔克斯',
#   'time': '2011-6',
#   'price': 39.5,
#   'star': 9.2,
#   'mark_num': 165530},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607b'),
#   'book': '红楼梦',
#   'author': '[清] 曹雪芹 著',
#   'time': '1996-12',
#   'price': 59.7,
#   'star': 9.6,
#   'mark_num': 157838},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607c'),
#   'book': '活着',
#   'author': '余华',
#   'time': '2012-8-1',
#   'price': 20.0,
#   'star': 9.3,
#   'mark_num': 151704},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607d'),
#   'book': '看见',
#   'author': '柴静',
#   'time': '2013-1-1',
#   'price': 39.8,
#   'star': 8.8,
#   'mark_num': 160894},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607e'),
#   'book': '不能承受的生命之轻',
#   'author': '[捷克] 米兰·昆德拉',
#   'time': '2003-7',
#   'price': 23.0,
#   'star': 8.5,
#   'mark_num': 154896},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871607f'),
#   'book': '平凡的世界（全三部）',
#   'author': '路遥',
#   'time': '2005-1',
#   'price': 64.0,
#   'star': 9.0,
#   'mark_num': 134885},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716080'),
#   'book': '达·芬奇密码',
#   'author': '[美] 丹·布朗',
#   'time': '2004-2',
#   'price': 28.0,
#   'star': 8.2,
#   'mark_num': 148828},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716081'),
#   'book': '三体Ⅱ',
#   'author': '刘慈欣',
#   'time': '2008-5',
#   'price': 32.0,
#   'star': 9.3,
#   'mark_num': 126385},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716082'),
#   'book': '三体Ⅲ',
#   'author': '刘慈欣',
#   'time': '2010-11',
#   'price': 38.0,
#   'star': 9.2,
#   'mark_num': 125878},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716083'),
#   'book': '简爱（英文全本）',
#   'author': '[英] 夏洛蒂·勃朗特',
#   'time': '2003-11',
#   'price': 18.0,
#   'star': 8.5,
#   'mark_num': 125815},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716084'),
#   'book': '我们仨',
#   'author': '杨绛',
#   'time': '2003-7',
#   'price': 18.8,
#   'star': 8.7,
#   'mark_num': 117606},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716085'),
#   'book': '天才在左 疯子在右',
#   'author': '高铭',
#   'time': '2010-2',
#   'price': 29.8,
#   'star': 8.2,
#   'mark_num': 126326},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716086'),
#   'book': '哈利·波特与魔法石',
#   'author': '[英] J. K. 罗琳',
#   'time': '2000-9',
#   'price': 19.5,
#   'star': 9.0,
#   'mark_num': 108026},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716087'),
#   'book': '傲慢与偏见',
#   'author': '[英] 奥斯丁',
#   'time': '1993-7',
#   'price': 13.0,
#   'star': 8.8,
#   'mark_num': 107648},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716088'),
#   'book': '明朝那些事儿（壹）',
#   'author': '当年明月',
#   'time': '2006-9',
#   'price': 24.8,
#   'star': 8.7,
#   'mark_num': 106523},
#  {'_id': ObjectId('5c3fda8044bb8c3fd8716089'),
#   'book': '目送',
#   'author': '龙应台',
#   'time': '2009-10',
#   'price': 39.0,
#   'star': 8.7,
#   'mark_num': 107156},
#  {'_id': ObjectId('5c3fda8044bb8c3fd871608a'),
#   'book': '飘',
#   'author': '[美国] 玛格丽特·米切尔',
#   'time': '2000-9',
#   'price': 40.0,
#   'star': 9.3,
#   'mark_num': 95983},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871608b'),
#   'book': '倾城之恋',
#   'author': '花城出版社',
#   'time': '1997-3-1',
#   'price': 11.0,
#   'star': 8.5,
#   'mark_num': 104589},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871608c'),
#   'book': '送你一颗子弹',
#   'author': '刘瑜',
#   'time': '2010-1',
#   'price': 25.0,
#   'star': 8.6,
#   'mark_num': 101628},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871608d'),
#   'book': '恶意',
#   'author': '[日] 东野圭吾',
#   'time': '2009-6',
#   'price': 18.0,
#   'star': 8.4,
#   'mark_num': 101573},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871608e'),
#   'book': '霍乱时期的爱情',
#   'author': '[哥伦比亚] 加西亚·马尔克斯',
#   'time': '2012-9-1',
#   'price': 39.5,
#   'star': 9.0,
#   'mark_num': 94677},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871608f'),
#   'book': '边城',
#   'author': '沈从文',
#   'time': '2002-4',
#   'price': 12.0,
#   'star': 8.6,
#   'mark_num': 94830},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716090'),
#   'book': '撒哈拉的故事',
#   'author': '三毛',
#   'time': '1976',
#   'price': 160.0,
#   'star': 9.0,
#   'mark_num': 88959},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716091'),
#   'book': '情人',
#   'author': '[法] 玛格丽特·杜拉斯',
#   'time': '2005-7',
#   'price': 20.0,
#   'star': 8.1,
#   'mark_num': 100737},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716092'),
#   'book': '许三观卖血记',
#   'author': '余华',
#   'time': '1998-9',
#   'price': 16.8,
#   'star': 8.7,
#   'mark_num': 90622},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716093'),
#   'book': '哈利·波特与阿兹卡班的囚徒',
#   'author': '[英] J. K. 罗琳',
#   'time': '2000-9',
#   'price': 26.5,
#   'star': 8.9,
#   'mark_num': 88257},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716094'),
#   'book': '狼图腾',
#   'author': '姜戎',
#   'time': '2004-4',
#   'price': 32.0,
#   'star': 8.3,
#   'mark_num': 95708},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716095'),
#   'book': '哈利·波特与火焰杯',
#   'author': '[英] J. K. 罗琳',
#   'time': '2001-5',
#   'price': 39.8,
#   'star': 9.0,
#   'mark_num': 85097},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716096'),
#   'book': '哈利·波特与密室',
#   'author': '[英] J. K. 罗琳',
#   'time': '2000-9',
#   'price': 22.0,
#   'star': 8.9,
#   'mark_num': 85242},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716097'),
#   'book': '穆斯林的葬礼',
#   'author': '霍达',
#   'time': '1988-12-1',
#   'price': 32.0,
#   'star': 8.2,
#   'mark_num': 91202},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716098'),
#   'book': '万历十五年',
#   'author': '[美] 黄仁宇',
#   'time': '1997-5',
#   'price': 18.0,
#   'star': 8.9,
#   'mark_num': 83005},
#  {'_id': ObjectId('5c3fda8144bb8c3fd8716099'),
#   'book': '1Q84 BOOK 1',
#   'author': '[日] 村上春树',
#   'time': '2010-5',
#   'price': 36.0,
#   'star': 8.3,
#   'mark_num': 88891},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609a'),
#   'book': '盗墓笔记',
#   'author': '南派三叔',
#   'time': '2007-1',
#   'price': 26.8,
#   'star': 8.3,
#   'mark_num': 84647},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609b'),
#   'book': '窗边的小豆豆',
#   'author': '[日] 黑柳彻子 著',
#   'time': '2003-1',
#   'price': 20.0,
#   'star': 8.7,
#   'mark_num': 78246},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609c'),
#   'book': '哈利·波特与混血王子',
#   'author': '[英] J. K. 罗琳',
#   'time': '2005-10',
#   'price': 58.0,
#   'star': 8.8,
#   'mark_num': 74615},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609d'),
#   'book': '黄金时代',
#   'author': '王小波',
#   'time': '1999-3',
#   'price': 19.0,
#   'star': 8.8,
#   'mark_num': 75582},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609e'),
#   'book': '向左走·向右走',
#   'author': '幾米',
#   'time': '2002-8',
#   'price': 16.0,
#   'star': 8.4,
#   'mark_num': 79384},
#  {'_id': ObjectId('5c3fda8144bb8c3fd871609f'),
#   'book': '莲花',
#   'author': '安妮宝贝',
#   'time': '2006-3',
#   'price': 25.0,
#   'star': 8.0,
#   'mark_num': 81995},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a0'),
#   'book': '苏菲的世界',
#   'author': '（挪威）乔斯坦·贾德',
#   'time': '1999-04',
#   'price': 26.8,
#   'star': 8.5,
#   'mark_num': 74629},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a1'),
#   'book': '人间失格',
#   'author': '太宰治',
#   'time': '2009年9月',
#   'price': 16.0,
#   'star': 8.3,
#   'mark_num': 76916},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a2'),
#   'book': '三国演义（全二册）',
#   'author': '[明] 罗贯中',
#   'time': '1998-05',
#   'price': 39.5,
#   'star': 9.2,
#   'mark_num': 67875},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a3'),
#   'book': '哈利·波特与凤凰社',
#   'author': '[英] J. K. 罗琳',
#   'time': '2003-9',
#   'price': 59.0,
#   'star': 8.7,
#   'mark_num': 70955},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a4'),
#   'book': '悟空传',
#   'author': '今何在',
#   'time': '2001-4',
#   'price': 14.8,
#   'star': 8.4,
#   'mark_num': 75238},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a5'),
#   'book': '牧羊少年奇幻之旅',
#   'author': '[巴西]保罗·柯艾略',
#   'time': '2009-3-1',
#   'price': 25.0,
#   'star': 8.6,
#   'mark_num': 72810},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a6'),
#   'book': '老人与海',
#   'author': '海明威',
#   'time': '1999-10',
#   'price': 8.2,
#   'star': 8.3,
#   'mark_num': 74487},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a7'),
#   'book': '天龙八部',
#   'author': '金庸',
#   'time': '1994-5',
#   'price': 96.0,
#   'star': 9.1,
#   'mark_num': 67456},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a8'),
#   'book': '1984',
#   'author': '[英] 乔治·奥威尔',
#   'time': '2010-4-1',
#   'price': 28.0,
#   'star': 9.3,
#   'mark_num': 65807},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160a9'),
#   'book': '人类简史',
#   'author': '[以色列]尤瓦尔·赫拉利',
#   'time': '2014-11',
#   'price': 68.0,
#   'star': 9.1,
#   'mark_num': 66819},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160aa'),
#   'book': '哈利·波特与死亡圣器',
#   'author': '[英] J. K. 罗琳',
#   'time': '2007-10',
#   'price': 66.0,
#   'star': 9.0,
#   'mark_num': 65846},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160ab'),
#   'book': '呼啸山庄',
#   'author': '（英）勃朗特',
#   'time': '1999-01-01',
#   'price': 27.3,
#   'star': 8.4,
#   'mark_num': 69065},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160ac'),
#   'book': '亲爱的安德烈',
#   'author': '龙应台',
#   'time': '2008-12',
#   'price': 26.0,
#   'star': 8.7,
#   'mark_num': 66696},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160ad'),
#   'book': '灿烂千阳',
#   'author': '[美] 卡勒德·胡赛尼',
#   'time': '2007-9',
#   'price': 28.0,
#   'star': 8.8,
#   'mark_num': 64369},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160ae'),
#   'book': '海边的卡夫卡',
#   'author': '[日] 村上春树',
#   'time': '2003-4',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 70214},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160af'),
#   'book': '基督山伯爵',
#   'author': '大仲马',
#   'time': '1991-12-1',
#   'price': 43.9,
#   'star': 9.0,
#   'mark_num': 62335},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b0'),
#   'book': '无声告白',
#   'author': '[美] 伍绮诗',
#   'time': '2015-7',
#   'price': 35.0,
#   'star': 8.2,
#   'mark_num': 68372},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b1'),
#   'book': '兄弟（上）',
#   'author': '余华',
#   'time': '2005-8',
#   'price': 16.0,
#   'star': 8.3,
#   'mark_num': 66048},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b2'),
#   'book': '笑傲江湖（全四册）',
#   'author': '金庸',
#   'time': '1994-5',
#   'price': 76.8,
#   'star': 9.0,
#   'mark_num': 59826},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b3'),
#   'book': '少有人走的路',
#   'author': '[美] M·斯科特·派克',
#   'time': '2007-1',
#   'price': 26.0,
#   'star': 8.4,
#   'mark_num': 64119},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b4'),
#   'book': '福尔摩斯探案全集（上中下）',
#   'author': '[英] 阿·柯南道尔',
#   'time': '1981-8',
#   'price': 53.0,
#   'star': 9.2,
#   'mark_num': 56833},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b5'),
#   'book': '白鹿原',
#   'author': '陈忠实',
#   'time': '1997-12',
#   'price': 28.0,
#   'star': 8.7,
#   'mark_num': 59686},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b6'),
#   'book': '茶花女',
#   'author': '小仲马',
#   'time': '1997-3',
#   'price': 9.0,
#   'star': 8.2,
#   'mark_num': 63808},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b7'),
#   'book': '一个陌生女人的来信',
#   'author': '[奥] 斯台芬·茨威格',
#   'time': '2007-7',
#   'price': 20.0,
#   'star': 8.7,
#   'mark_num': 59435},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b8'),
#   'book': '沉默的大多数',
#   'author': '王小波',
#   'time': '1997-10',
#   'price': 27.0,
#   'star': 9.1,
#   'mark_num': 55913},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160b9'),
#   'book': '民主的细节',
#   'author': '刘瑜',
#   'time': '2009-6',
#   'price': 25.0,
#   'star': 8.6,
#   'mark_num': 59255},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160ba'),
#   'book': '鲁滨逊漂流记',
#   'author': '[英] 笛福',
#   'time': '2002-1',
#   'price': 9.2,
#   'star': 8.0,
#   'mark_num': 63226},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160bb'),
#   'book': '情书',
#   'author': '[日] 岩井俊二',
#   'time': '2004-7',
#   'price': 18.0,
#   'star': 8.6,
#   'mark_num': 57289},
#  {'_id': ObjectId('5c3fda8144bb8c3fd87160bc'),
#   'book': '局外人',
#   'author': '[法] 阿尔贝·加缪',
#   'time': '2010-9',
#   'price': 22.0,
#   'star': 9.0,
#   'mark_num': 53816},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160bd'),
#   'book': '遇见未知的自己',
#   'author': '张德芬',
#   'time': '2008-1',
#   'price': 29.0,
#   'star': 8.0,
#   'mark_num': 60473},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160be'),
#   'book': '神雕侠侣',
#   'author': '金庸',
#   'time': '1994-5',
#   'price': 76.8,
#   'star': 8.8,
#   'mark_num': 54001},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160bf'),
#   'book': '东方快车谋杀案',
#   'author': '[英] 阿加莎·克里斯蒂',
#   'time': '2006-5',
#   'price': 18.0,
#   'star': 9.0,
#   'mark_num': 51855},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c0'),
#   'book': '肖申克的救赎',
#   'author': '[美] 斯蒂芬·金',
#   'time': '2006-7',
#   'price': 29.9,
#   'star': 9.1,
#   'mark_num': 48880},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c1'),
#   'book': '当我谈跑步时我谈些什么',
#   'author': '[日] 村上春树',
#   'time': '2009-1',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 55108},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c2'),
#   'book': '了不起的盖茨比',
#   'author': '菲茨杰拉德',
#   'time': '2004-06',
#   'price': 12.0,
#   'star': 8.3,
#   'mark_num': 53250},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c3'),
#   'book': '骆驼祥子',
#   'author': '老舍',
#   'time': '2000-3-1',
#   'price': 12.0,
#   'star': 8.3,
#   'mark_num': 53165},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c4'),
#   'book': '无人生还',
#   'author': '[英] 阿加莎・克里斯蒂',
#   'time': '2008-3',
#   'price': 19.0,
#   'star': 8.9,
#   'mark_num': 49589},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c5'),
#   'book': '巴黎圣母院',
#   'author': '[法]雨果',
#   'time': '1982-6',
#   'price': 22.5,
#   'star': 8.3,
#   'mark_num': 53024},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c6'),
#   'book': '羊脂球',
#   'author': '（法）莫泊桑',
#   'time': '2007-6',
#   'price': 13.5,
#   'star': 8.1,
#   'mark_num': 54027},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c7'),
#   'book': '房思琪的初恋乐园',
#   'author': '林奕含',
#   'time': '2018-1',
#   'price': 45.0,
#   'star': 9.2,
#   'mark_num': 47453},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c8'),
#   'book': '呐喊',
#   'author': '鲁迅',
#   'time': '1973年3月',
#   'price': 0.36,
#   'star': 8.9,
#   'mark_num': 47953},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160c9'),
#   'book': '爱你就像爱生命',
#   'author': '王小波',
#   'time': '2008-5',
#   'price': 18.0,
#   'star': 8.8,
#   'mark_num': 48094},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ca'),
#   'book': '乌合之众',
#   'author': '（法）勒庞',
#   'time': '2011-5-1',
#   'price': 16.0,
#   'star': 8.2,
#   'mark_num': 51575},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160cb'),
#   'book': '动物农场',
#   'author': '[英] 乔治·奥威尔',
#   'time': '2007-3',
#   'price': 10.0,
#   'star': 9.2,
#   'mark_num': 45208},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160cc'),
#   'book': '红玫瑰与白玫瑰',
#   'author': '张爱玲',
#   'time': '1996-06',
#   'price': 12.8,
#   'star': 8.4,
#   'mark_num': 49864},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160cd'),
#   'book': '这些人，那些事',
#   'author': '吴念真',
#   'time': '2011-9',
#   'price': 28.0,
#   'star': 8.8,
#   'mark_num': 47142},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ce'),
#   'book': '这些都是你给我的爱',
#   'author': '文：安东尼',
#   'time': '2010-3',
#   'price': 24.8,
#   'star': 8.4,
#   'mark_num': 48955},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160cf'),
#   'book': '巨人的陨落',
#   'author': '[英] 肯·福莱特',
#   'time': '2016-5-1',
#   'price': 129.8,
#   'star': 8.9,
#   'mark_num': 45655},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d0'),
#   'book': '喜宝',
#   'author': '亦舒',
#   'time': '2007-2',
#   'price': 22.0,
#   'star': 8.0,
#   'mark_num': 50481},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d1'),
#   'book': '安徒生童话故事集',
#   'author': '（丹麦）安徒生',
#   'time': '1997-08',
#   'price': 25.0,
#   'star': 9.2,
#   'mark_num': 43405},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d2'),
#   'book': '陪安东尼度过漫长岁月',
#   'author': '安东尼',
#   'time': '2008-3',
#   'price': 18.0,
#   'star': 8.3,
#   'mark_num': 47849},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d3'),
#   'book': '鬼吹灯之精绝古城',
#   'author': '天下霸唱',
#   'time': '2006',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 47877},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d4'),
#   'book': '华胥引（全二册）',
#   'author': '唐七公子',
#   'time': '2011-1',
#   'price': 39.8,
#   'star': 8.4,
#   'mark_num': 46883},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d5'),
#   'book': '半生缘',
#   'author': '张爱玲',
#   'time': '2006-12',
#   'price': 28.0,
#   'star': 8.6,
#   'mark_num': 44677},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d6'),
#   'book': '射雕英雄传（全四册）',
#   'author': '金庸',
#   'time': '1999-04',
#   'price': 47.0,
#   'star': 8.9,
#   'mark_num': 39814},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d7'),
#   'book': '地下铁',
#   'author': '幾米',
#   'time': '2002-2',
#   'price': 32.0,
#   'star': 8.3,
#   'mark_num': 42526},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d8'),
#   'book': '阿Q正传',
#   'author': '鲁迅',
#   'time': '2003-7',
#   'price': 14.5,
#   'star': 8.7,
#   'mark_num': 40021},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160d9'),
#   'book': '如何阅读一本书',
#   'author': '[美] 莫提默·J. 艾德勒',
#   'time': '2004-1',
#   'price': 38.0,
#   'star': 8.4,
#   'mark_num': 41405},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160da'),
#   'book': '一个人的朝圣',
#   'author': '【英】蕾秋·乔伊斯',
#   'time': '2013-9-1',
#   'price': 32.8,
#   'star': 8.1,
#   'mark_num': 42816},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160db'),
#   'book': '一只特立独行的猪',
#   'author': '王小波',
#   'time': '2006-4',
#   'price': 18.8,
#   'star': 8.8,
#   'mark_num': 38119},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160dc'),
#   'book': '城南旧事',
#   'author': '林海音 文',
#   'time': '2003-7',
#   'price': 16.0,
#   'star': 9.0,
#   'mark_num': 37223},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160dd'),
#   'book': '梦里花落知多少',
#   'author': '三毛',
#   'time': '2007-6',
#   'price': 28.0,
#   'star': 8.8,
#   'mark_num': 37818},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160de'),
#   'book': '月亮忘記了',
#   'author': '幾米',
#   'time': '2000-2-1',
#   'price': 299.0,
#   'star': 8.6,
#   'mark_num': 38336},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160df'),
#   'book': '孤独六讲',
#   'author': '蒋勋',
#   'time': '2009-10-1',
#   'price': 36.0,
#   'star': 8.1,
#   'mark_num': 40943},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e0'),
#   'book': '此间的少年',
#   'author': '江南',
#   'time': '2004-1',
#   'price': 25.0,
#   'star': 8.4,
#   'mark_num': 39028},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e1'),
#   'book': '我不喜欢这世界，我只喜欢你',
#   'author': '乔一',
#   'time': '2015-5-1',
#   'price': 29.8,
#   'star': 8.0,
#   'mark_num': 38313},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e2'),
#   'book': '孩子你慢慢来',
#   'author': '龙应台',
#   'time': '2009-12-1',
#   'price': 28.0,
#   'star': 8.8,
#   'mark_num': 36685},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e3'),
#   'book': '步步惊心',
#   'author': '桐华',
#   'time': '2006-6',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 39602},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e4'),
#   'book': '刀锋',
#   'author': '[英]毛姆',
#   'time': '2007-3',
#   'price': 18.0,
#   'star': 9.0,
#   'mark_num': 35270},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e5'),
#   'book': '格林童话全集',
#   'author': '格林兄弟',
#   'time': '1994-11',
#   'price': 21.45,
#   'star': 9.0,
#   'mark_num': 35404},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e6'),
#   'book': '一個人住第5年',
#   'author': '高木直子',
#   'time': '2004-12-1',
#   'price': 220.0,
#   'star': 8.4,
#   'mark_num': 37027},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e7'),
#   'book': '麦琪的礼物',
#   'author': '[美] 欧·亨利',
#   'time': '2003-7',
#   'price': 25.0,
#   'star': 8.6,
#   'mark_num': 35846},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e8'),
#   'book': '荆棘鸟',
#   'author': '[澳] 考琳·麦卡洛',
#   'time': '1998-7',
#   'price': 28.0,
#   'star': 8.6,
#   'mark_num': 35422},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160e9'),
#   'book': '常识',
#   'author': '梁文道',
#   'time': '2009-1',
#   'price': 38.0,
#   'star': 8.1,
#   'mark_num': 37918},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ea'),
#   'book': '寻路中国',
#   'author': '[美] 彼得·海斯勒',
#   'time': '2011-1',
#   'price': 33.0,
#   'star': 9.0,
#   'mark_num': 33765},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160eb'),
#   'book': '哭泣的骆驼',
#   'author': '三毛',
#   'time': '2003-6',
#   'price': 15.8,
#   'star': 8.9,
#   'mark_num': 33616},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ec'),
#   'book': '你好，旧时光（上 下）',
#   'author': '八月长安',
#   'time': '2009-12',
#   'price': 39.8,
#   'star': 8.8,
#   'mark_num': 34159},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ed'),
#   'book': '尘埃落定',
#   'author': '阿来',
#   'time': '1998-3-1',
#   'price': 22.0,
#   'star': 8.4,
#   'mark_num': 35782},
#  {'_id': ObjectId('5c3fda8244bb8c3fd87160ee'),
#   'book': '时间旅行者的妻子',
#   'author': '[美] 奥德丽·尼芬格',
#   'time': '2007-4',
#   'price': 29.9,
#   'star': 8.1,
#   'mark_num': 37112},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160ef'),
#   'book': '那些回不去的年少时光',
#   'author': '桐华',
#   'time': '2010-01',
#   'price': 23.8,
#   'star': 8.5,
#   'mark_num': 34320},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f0'),
#   'book': '金锁记',
#   'author': '张爱玲',
#   'time': '2005-6',
#   'price': 13.5,
#   'star': 8.5,
#   'mark_num': 34601},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f1'),
#   'book': '菊与刀',
#   'author': '（美）鲁思・本尼迪克特',
#   'time': '1990-6',
#   'price': 16.0,
#   'star': 8.2,
#   'mark_num': 36224},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f2'),
#   'book': '失恋33天',
#   'author': '鲍鲸鲸',
#   'time': '2010-1',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 35850},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f3'),
#   'book': '朝花夕拾',
#   'author': '鲁迅',
#   'time': '1972年4月',
#   'price': 0.25,
#   'star': 8.7,
#   'mark_num': 32720},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f4'),
#   'book': '悲惨世界（上中下）',
#   'author': '[法] 雨果',
#   'time': '1992-6',
#   'price': 66.0,
#   'star': 8.9,
#   'mark_num': 31672},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f5'),
#   'book': '海贼王',
#   'author': '尾田荣一郎',
#   'time': '2007-11',
#   'price': 7.5,
#   'star': 9.5,
#   'mark_num': 29487},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f6'),
#   'book': '查令十字街84号',
#   'author': '[美] 海莲·汉芙',
#   'time': '2005-05-01',
#   'price': 18.0,
#   'star': 8.3,
#   'mark_num': 34293},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f7'),
#   'book': '球状闪电',
#   'author': '刘慈欣',
#   'time': '2005-6',
#   'price': 22.0,
#   'star': 8.7,
#   'mark_num': 32351},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f8'),
#   'book': '鹿鼎记（全五册）',
#   'author': '金庸',
#   'time': '2008-3',
#   'price': 108.0,
#   'star': 8.8,
#   'mark_num': 31808},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160f9'),
#   'book': '史蒂夫·乔布斯传',
#   'author': '[美] 沃尔特·艾萨克森',
#   'time': '2011-10-24',
#   'price': 68.0,
#   'star': 8.7,
#   'mark_num': 32202},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160fa'),
#   'book': '杀死一只知更鸟',
#   'author': '[美] 哈珀·李',
#   'time': '2012-9',
#   'price': 32.0,
#   'star': 9.2,
#   'mark_num': 30050},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160fb'),
#   'book': '历史深处的忧虑',
#   'author': '林达',
#   'time': '1997-5',
#   'price': 19.0,
#   'star': 9.0,
#   'mark_num': 30380},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160fc'),
#   'book': '东霓',
#   'author': '笛安',
#   'time': '2010-7-1',
#   'price': 26.8,
#   'star': 8.1,
#   'mark_num': 34151},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160fd'),
#   'book': '长恨歌',
#   'author': '王安忆',
#   'time': '2003-8',
#   'price': 22.0,
#   'star': 8.2,
#   'mark_num': 33828},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160fe'),
#   'book': '飞鸟集',
#   'author': '[印] 罗宾德拉纳德·泰戈尔',
#   'time': '2004-6',
#   'price': 16.8,
#   'star': 8.9,
#   'mark_num': 30677},
#  {'_id': ObjectId('5c3fda8344bb8c3fd87160ff'),
#   'book': '你一定爱读的极简欧洲史',
#   'author': '约翰·赫斯特（John Hirst）',
#   'time': '2011-11-25',
#   'price': 25.0,
#   'star': 8.2,
#   'mark_num': 33208},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716100'),
#   'book': '大地之灯',
#   'author': '七堇年',
#   'time': '2007-1',
#   'price': 22.0,
#   'star': 8.2,
#   'mark_num': 32750},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716101'),
#   'book': '富爸爸，穷爸爸',
#   'author': '（美）罗伯特・T・清崎',
#   'time': '2000-09',
#   'price': 18.8,
#   'star': 8.2,
#   'mark_num': 32022},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716102'),
#   'book': '倚天屠龙记(共四册)',
#   'author': '金庸',
#   'time': '1999-04',
#   'price': 0.0,
#   'star': 8.5,
#   'mark_num': 30515},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716103'),
#   'book': '伊豆的舞女',
#   'author': '[日] 川端康成',
#   'time': '2002-2',
#   'price': 23.8,
#   'star': 8.2,
#   'mark_num': 32111},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716104'),
#   'book': '月亮与六便士',
#   'author': '[英] 威廉·萨默塞特·毛姆',
#   'time': '2017-1-1',
#   'price': 39.8,
#   'star': 8.8,
#   'mark_num': 30082},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716105'),
#   'book': '一九八四·动物农场',
#   'author': '[英] 乔治·奥威尔',
#   'time': '2003-4',
#   'price': 23.0,
#   'star': 9.3,
#   'mark_num': 27501},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716106'),
#   'book': '香水',
#   'author': '[德] 帕·聚斯金德',
#   'time': '2005-5',
#   'price': 20.0,
#   'star': 8.5,
#   'mark_num': 30033},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716107'),
#   'book': '海底两万里',
#   'author': '[法国] 儒尔·凡尔纳',
#   'time': '2002-9',
#   'price': 19.5,
#   'star': 8.4,
#   'mark_num': 30363},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716108'),
#   'book': '橙',
#   'author': '安东尼',
#   'time': '2010-10',
#   'price': 28.8,
#   'star': 8.2,
#   'mark_num': 30910},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716109'),
#   'book': '看不见的城市',
#   'author': '[意大利]伊塔洛·卡尔维诺',
#   'time': '2006-8',
#   'price': 16.0,
#   'star': 8.8,
#   'mark_num': 28880},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610a'),
#   'book': '水浒传（全二册）',
#   'author': '[明] 施耐庵',
#   'time': '1997-1',
#   'price': 50.6,
#   'star': 8.5,
#   'mark_num': 29434},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610b'),
#   'book': '中国历代政治得失',
#   'author': '钱穆',
#   'time': '2001',
#   'price': 12.0,
#   'star': 9.1,
#   'mark_num': 27434},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610c'),
#   'book': '时间简史',
#   'author': '[英] 史蒂芬·霍金',
#   'time': '2010-4',
#   'price': 45.0,
#   'star': 8.8,
#   'mark_num': 28439},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610d'),
#   'book': '影响力',
#   'author': '[美] 罗伯特·西奥迪尼',
#   'time': '2006-5',
#   'price': 45.0,
#   'star': 8.6,
#   'mark_num': 28957},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610e'),
#   'book': '雷雨',
#   'author': '曹禺',
#   'time': '1999-05',
#   'price': 9.2,
#   'star': 8.6,
#   'mark_num': 29425},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871610f'),
#   'book': '匆匆那年（上下）',
#   'author': '九夜茴',
#   'time': '2008-1',
#   'price': 29.0,
#   'star': 8.3,
#   'mark_num': 30455},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716110'),
#   'book': '红与黑',
#   'author': '斯丹达尔',
#   'time': '1993-7-1',
#   'price': 20.0,
#   'star': 8.2,
#   'mark_num': 30666},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716111'),
#   'book': '世界尽头与冷酷仙境',
#   'author': '[日] 村上春树',
#   'time': '2002-12',
#   'price': 23.0,
#   'star': 8.6,
#   'mark_num': 29147},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716112'),
#   'book': '江城',
#   'author': '[美] 彼得·海斯勒',
#   'time': '2012-1',
#   'price': 36.0,
#   'star': 9.0,
#   'mark_num': 27295},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716113'),
#   'book': '你今天真好看',
#   'author': '[美]莉兹•克里莫',
#   'time': '2015-8',
#   'price': 39.0,
#   'star': 8.7,
#   'mark_num': 28539},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716114'),
#   'book': '西游记（全二册）',
#   'author': '吴承恩',
#   'time': '2004-8',
#   'price': 47.2,
#   'star': 8.8,
#   'mark_num': 27750},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716115'),
#   'book': '把时间当作朋友',
#   'author': '李笑来',
#   'time': '2009-6',
#   'price': 32.0,
#   'star': 8.5,
#   'mark_num': 29136},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716116'),
#   'book': '冰与火之歌（卷一）',
#   'author': '[美] 乔治·R. R. 马丁',
#   'time': '2005-5',
#   'price': 68.0,
#   'star': 9.3,
#   'mark_num': 26013},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716117'),
#   'book': '瓦尔登湖',
#   'author': '[美] 梭罗',
#   'time': '2006-8',
#   'price': 11.0,
#   'star': 8.4,
#   'mark_num': 29211},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716118'),
#   'book': '最好的我们',
#   'author': '八月长安',
#   'time': '2013-8-5',
#   'price': 55.0,
#   'star': 8.8,
#   'mark_num': 27026},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716119'),
#   'book': '陆犯焉识',
#   'author': '严歌苓',
#   'time': '2011-10',
#   'price': 35.0,
#   'star': 8.8,
#   'mark_num': 27216},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611a'),
#   'book': '往事并不如烟',
#   'author': '章诒和',
#   'time': '2004-1',
#   'price': 35.0,
#   'star': 8.6,
#   'mark_num': 27948},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611b'),
#   'book': '那些年，我们一起追的女孩',
#   'author': '九把刀',
#   'time': '2007-1',
#   'price': 20.0,
#   'star': 8.2,
#   'mark_num': 29540},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611c'),
#   'book': '狂人日记',
#   'author': '鲁迅',
#   'time': '2006-3',
#   'price': 39.8,
#   'star': 8.7,
#   'mark_num': 27307},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611d'),
#   'book': '七夜雪',
#   'author': '沧月',
#   'time': '2006-10',
#   'price': 25.0,
#   'star': 8.4,
#   'mark_num': 27770},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611e'),
#   'book': '阿狸·梦之城堡',
#   'author': 'hans',
#   'time': '2009-1',
#   'price': 36.8,
#   'star': 9.0,
#   'mark_num': 26077},
#  {'_id': ObjectId('5c3fda8344bb8c3fd871611f'),
#   'book': 'ZOO',
#   'author': '[日] 乙一',
#   'time': '2007-10',
#   'price': 20.0,
#   'star': 8.6,
#   'mark_num': 27222},
#  {'_id': ObjectId('5c3fda8344bb8c3fd8716120'),
#   'book': '天使与魔鬼',
#   'author': '[美] 丹.布朗',
#   'time': '2005-2',
#   'price': 29.8,
#   'star': 8.1,
#   'mark_num': 28630},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716121'),
#   'book': '夏洛的网',
#   'author': '[美] E.B.怀特',
#   'time': '2004-5',
#   'price': 17.0,
#   'star': 8.5,
#   'mark_num': 27084},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716122'),
#   'book': '自控力',
#   'author': '[美]  凯利·麦格尼格尔',
#   'time': '2012-8',
#   'price': 39.8,
#   'star': 8.3,
#   'mark_num': 28067},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716123'),
#   'book': '蔷薇岛屿',
#   'author': '安妮宝贝',
#   'time': '2002-8',
#   'price': 18.0,
#   'star': 8.0,
#   'mark_num': 29011},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716124'),
#   'book': '呼兰河传',
#   'author': '萧红',
#   'time': '2005-01',
#   'price': 19.0,
#   'star': 8.9,
#   'mark_num': 25725},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716125'),
#   'book': '我与地坛',
#   'author': '史铁生',
#   'time': '2002-5',
#   'price': 25.0,
#   'star': 9.0,
#   'mark_num': 24940},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716126'),
#   'book': '变形记',
#   'author': '[奥] 卡夫卡',
#   'time': '2003-4',
#   'price': 16.0,
#   'star': 8.4,
#   'mark_num': 26853},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716127'),
#   'book': '国境以南 太阳以西',
#   'author': '[日] 村上春树',
#   'time': '2001-8',
#   'price': 13.5,
#   'star': 8.3,
#   'mark_num': 27384},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716128'),
#   'book': '最初的爱情 最后的仪式',
#   'author': '[英] 伊恩·麦克尤恩',
#   'time': '2010-2',
#   'price': 22.0,
#   'star': 8.0,
#   'mark_num': 28146},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716129'),
#   'book': '浮生六记',
#   'author': '（清）沈复',
#   'time': '1999/1',
#   'price': 5.7,
#   'star': 8.9,
#   'mark_num': 25295},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612a'),
#   'book': '京华烟云',
#   'author': '林语堂',
#   'time': '2005-7',
#   'price': 43.0,
#   'star': 8.5,
#   'mark_num': 25594},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612b'),
#   'book': '人生',
#   'author': '路遥',
#   'time': '2009-5',
#   'price': 20.0,
#   'star': 8.4,
#   'mark_num': 25423},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612c'),
#   'book': '生活在别处',
#   'author': '[捷克] 米兰·昆德拉',
#   'time': '2004-5',
#   'price': 25.0,
#   'star': 8.4,
#   'mark_num': 25954},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612d'),
#   'book': '没有色彩的多崎作和他的巡礼之年',
#   'author': '[日] 村上春树',
#   'time': '2013-10-1',
#   'price': 39.5,
#   'star': 8.2,
#   'mark_num': 25978},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612e'),
#   'book': '人性的弱点全集',
#   'author': '[美] 戴尔·卡耐基',
#   'time': '2008-1',
#   'price': 25.0,
#   'star': 8.3,
#   'mark_num': 25610},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871612f'),
#   'book': '佛祖在一号线',
#   'author': '李海鹏',
#   'time': '2010-6',
#   'price': 25.0,
#   'star': 8.2,
#   'mark_num': 26078},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716130'),
#   'book': '心是孤独的猎手',
#   'author': '[美] 卡森·麦卡勒斯',
#   'time': '2005-8',
#   'price': 25.0,
#   'star': 8.5,
#   'mark_num': 24875},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716131'),
#   'book': '文学回忆录（全2册）',
#   'author': '木心 讲述',
#   'time': '2013-1-10',
#   'price': 98.0,
#   'star': 9.2,
#   'mark_num': 22788},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716132'),
#   'book': '设计中的设计',
#   'author': '[日] 原研哉',
#   'time': '2006-11',
#   'price': 48.0,
#   'star': 8.6,
#   'mark_num': 24432},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716133'),
#   'book': '一句顶一万句',
#   'author': '刘震云',
#   'time': '2009-3',
#   'price': 29.8,
#   'star': 8.7,
#   'mark_num': 23945},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716134'),
#   'book': '我执',
#   'author': '梁文道',
#   'time': '2010-10',
#   'price': 35.0,
#   'star': 8.0,
#   'mark_num': 26092},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716135'),
#   'book': '激荡三十年（上）',
#   'author': '吴晓波',
#   'time': '2007-1',
#   'price': 35.0,
#   'star': 8.8,
#   'mark_num': 23361},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716136'),
#   'book': '尼罗河上的惨案',
#   'author': '[英] 阿加莎·克里斯蒂',
#   'time': '2006-5',
#   'price': 22.0,
#   'star': 8.7,
#   'mark_num': 23583},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716137'),
#   'book': '偷书贼',
#   'author': '[澳] 马克斯·苏萨克',
#   'time': '2007-8',
#   'price': 25.0,
#   'star': 8.0,
#   'mark_num': 25419},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716138'),
#   'book': '未来简史',
#   'author': '[以色列] 尤瓦尔·赫拉利',
#   'time': '2017-1',
#   'price': 68.0,
#   'star': 8.4,
#   'mark_num': 23223},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716139'),
#   'book': '九州·缥缈录',
#   'author': '江南',
#   'time': '2005-6',
#   'price': 20.0,
#   'star': 8.8,
#   'mark_num': 21974},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613a'),
#   'book': '项链',
#   'author': '[法] 莫泊桑',
#   'time': '2005-2',
#   'price': 28.0,
#   'star': 8.3,
#   'mark_num': 23358},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613b'),
#   'book': '我的精神家园',
#   'author': '王小波',
#   'time': '1997',
#   'price': 18.8,
#   'star': 9.1,
#   'mark_num': 21309},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613c'),
#   'book': '妻妾成群',
#   'author': '苏童',
#   'time': '2004-8',
#   'price': 23.0,
#   'star': 8.2,
#   'mark_num': 23507},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613d'),
#   'book': '野火集',
#   'author': '龙应台',
#   'time': '2005-8',
#   'price': 25.0,
#   'star': 8.8,
#   'mark_num': 21697},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613e'),
#   'book': '父与子全集',
#   'author': '[德] 埃·奥·卜劳恩 绘',
#   'time': '2003-4',
#   'price': 20.0,
#   'star': 9.2,
#   'mark_num': 20474},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871613f'),
#   'book': '占星术杀人魔法',
#   'author': '[日] 岛田庄司',
#   'time': '2008-9',
#   'price': 28.0,
#   'star': 8.3,
#   'mark_num': 22528},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716140'),
#   'book': '浪潮之巅',
#   'author': '吴军',
#   'time': '2011-8',
#   'price': 55.0,
#   'star': 9.1,
#   'mark_num': 20451},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716141'),
#   'book': '舞！舞！舞！',
#   'author': '[日] 村上春树',
#   'time': '2002-6',
#   'price': 25.0,
#   'star': 8.3,
#   'mark_num': 22548},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716142'),
#   'book': '海子的诗',
#   'author': '海子',
#   'time': '1999-04',
#   'price': 15.4,
#   'star': 8.9,
#   'mark_num': 20780},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716143'),
#   'book': '人间词话',
#   'author': '王国维',
#   'time': '1998-12-01',
#   'price': 9.8,
#   'star': 9.0,
#   'mark_num': 20506},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716144'),
#   'book': '罗生门',
#   'author': '[日]芥川龙之介',
#   'time': '2008-7',
#   'price': 12.0,
#   'star': 8.7,
#   'mark_num': 21390},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716145'),
#   'book': '教父',
#   'author': '[美]马里奥·普佐',
#   'time': '1997-8',
#   'price': 23.3,
#   'star': 9.0,
#   'mark_num': 20247},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716146'),
#   'book': '娱乐至死',
#   'author': '[美] 尼尔·波兹曼',
#   'time': '2011-6',
#   'price': 29.8,
#   'star': 8.5,
#   'mark_num': 21524},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716147'),
#   'book': '第一炉香',
#   'author': '张爱玲',
#   'time': '1997-3',
#   'price': 11.5,
#   'star': 8.4,
#   'mark_num': 21933},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716148'),
#   'book': '芳华',
#   'author': '严歌苓',
#   'time': '2017-4',
#   'price': 39.0,
#   'star': 8.1,
#   'mark_num': 22486},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716149'),
#   'book': '一千零一夜',
#   'author': '纳训',
#   'time': '2003-01',
#   'price': 22.0,
#   'star': 8.6,
#   'mark_num': 20975},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614a'),
#   'book': '高效能人士的七个习惯（精华版）',
#   'author': '[美] 史蒂芬·柯维',
#   'time': '2011-6',
#   'price': 29.0,
#   'star': 8.2,
#   'mark_num': 21784},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614b'),
#   'book': '我的天才女友',
#   'author': '[意] 埃莱娜·费兰特',
#   'time': '2017-1',
#   'price': 42.0,
#   'star': 8.5,
#   'mark_num': 21533},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614c'),
#   'book': '斯通纳',
#   'author': '[美] 约翰·威廉斯',
#   'time': '2016-1',
#   'price': 39.0,
#   'star': 8.8,
#   'mark_num': 20218},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614d'),
#   'book': '面纱',
#   'author': '(英)W.萨默塞特·毛姆',
#   'time': '2012-05-01',
#   'price': 32.0,
#   'star': 8.7,
#   'mark_num': 20479},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614e'),
#   'book': '动物凶猛',
#   'author': '王朔',
#   'time': '2004-2',
#   'price': 15.5,
#   'star': 8.3,
#   'mark_num': 21506},
#  {'_id': ObjectId('5c3fda8444bb8c3fd871614f'),
#   'book': '雨季不再来',
#   'author': '三毛',
#   'time': '2007-7',
#   'price': 28.0,
#   'star': 8.7,
#   'mark_num': 20249},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716150'),
#   'book': '子不语1',
#   'author': '夏达',
#   'time': '2009-12',
#   'price': 36.0,
#   'star': 9.0,
#   'mark_num': 19099},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716151'),
#   'book': '小姨多鹤',
#   'author': '严歌苓',
#   'time': '2008-4',
#   'price': 28.0,
#   'star': 8.6,
#   'mark_num': 20349},
#  {'_id': ObjectId('5c3fda8444bb8c3fd8716152'),
#   'book': '罗杰疑案',
#   'author': '[英] 阿加莎·克里斯蒂',
#   'time': '2006-5',
#   'price': 21.0,
#   'star': 8.9,
#   'mark_num': 19328},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716153'),
#   'book': '观念的水位',
#   'author': '刘瑜',
#   'time': '2013-1',
#   'price': 36.0,
#   'star': 8.3,
#   'mark_num': 20960},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716154'),
#   'book': '万水千山走遍',
#   'author': '三毛',
#   'time': '2003-08',
#   'price': 13.8,
#   'star': 8.8,
#   'mark_num': 19453},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716155'),
#   'book': '夹边沟记事',
#   'author': '杨显惠',
#   'time': '2008-09',
#   'price': 34.0,
#   'star': 9.2,
#   'mark_num': 18410},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716156'),
#   'book': '巨流河',
#   'author': '齐邦媛',
#   'time': '2010-10',
#   'price': 39.0,
#   'star': 8.7,
#   'mark_num': 19709},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716157'),
#   'book': '爱的艺术',
#   'author': '[美] 艾·弗洛姆',
#   'time': '2008-4',
#   'price': 15.0,
#   'star': 8.8,
#   'mark_num': 19263},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716158'),
#   'book': '哈姆莱特',
#   'author': '[英] 莎士比亚',
#   'time': '2001-1',
#   'price': 7.0,
#   'star': 8.5,
#   'mark_num': 20056},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716159'),
#   'book': '中国大历史',
#   'author': '黄仁宇',
#   'time': '2007-2',
#   'price': 19.0,
#   'star': 8.3,
#   'mark_num': 20700},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615a'),
#   'book': '台北人',
#   'author': '白先勇',
#   'time': '2010-10',
#   'price': 38.0,
#   'star': 8.9,
#   'mark_num': 18926},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615b'),
#   'book': '寻羊冒险记',
#   'author': '[日] 村上春树',
#   'time': '2001-8',
#   'price': 18.8,
#   'star': 8.1,
#   'mark_num': 20863},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615c'),
#   'book': '动物庄园',
#   'author': '（英）乔治·奥威尔',
#   'time': '2000-08',
#   'price': 18.0,
#   'star': 9.1,
#   'mark_num': 18243},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615d'),
#   'book': '带一本书去巴黎',
#   'author': '林达',
#   'time': '2002-5',
#   'price': 35.0,
#   'star': 8.5,
#   'mark_num': 19441},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615e'),
#   'book': '白银时代',
#   'author': '王小波',
#   'time': '1997-5',
#   'price': 10.0,
#   'star': 8.4,
#   'mark_num': 19844},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871615f'),
#   'book': '雾都孤儿',
#   'author': '[英]狄更斯',
#   'time': '1991-7',
#   'price': 10.1,
#   'star': 8.1,
#   'mark_num': 20479},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716160'),
#   'book': '云中歌1',
#   'author': '桐华',
#   'time': '2007-9',
#   'price': 24.8,
#   'star': 8.1,
#   'mark_num': 20378},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716161'),
#   'book': '告白',
#   'author': '湊佳苗',
#   'time': '2009年8月31日',
#   'price': 250.0,
#   'star': 8.6,
#   'mark_num': 18726},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716162'),
#   'book': '琅琊榜',
#   'author': '海宴',
#   'time': '2007-12',
#   'price': 49.8,
#   'star': 8.5,
#   'mark_num': 18588},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716163'),
#   'book': '枪炮、病菌与钢铁',
#   'author': '[美] 贾雷德·戴蒙德',
#   'time': '2006-4-1',
#   'price': 45.0,
#   'star': 8.8,
#   'mark_num': 18397},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716164'),
#   'book': '来不及说我爱你',
#   'author': '匪我思存',
#   'time': '2006-9',
#   'price': 20.0,
#   'star': 8.1,
#   'mark_num': 20037},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716165'),
#   'book': '新参者',
#   'author': '[日] 东野圭吾',
#   'time': '2011-9',
#   'price': 28.0,
#   'star': 8.4,
#   'mark_num': 19442},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716166'),
#   'book': '退步集',
#   'author': '陈丹青',
#   'time': '2005-1',
#   'price': 38.0,
#   'star': 8.1,
#   'mark_num': 19986},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716167'),
#   'book': '相约星期二',
#   'author': '[美] 米奇·阿尔博姆',
#   'time': '2007-7',
#   'price': 19.0,
#   'star': 8.4,
#   'mark_num': 19142},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716168'),
#   'book': '红拂夜奔',
#   'author': '王小波',
#   'time': '2005-1',
#   'price': 28.0,
#   'star': 8.6,
#   'mark_num': 18550},
#  {'_id': ObjectId('5c3fda8544bb8c3fd8716169'),
#   'book': '可爱的洪水猛兽',
#   'author': '韩寒',
#   'time': '2009-08-01',
#   'price': 25.0,
#   'star': 8.1,
#   'mark_num': 19780},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871616a'),
#   'book': '星空',
#   'author': '幾米',
#   'time': '2009-5-1',
#   'price': 369.0,
#   'star': 9.0,
#   'mark_num': 17104},
#  {'_id': ObjectId('5c3fda8544bb8c3fd871616b'),
#   'book': '后宫·甄嬛传Ⅰ',
#   'author': '流潋紫',
#   'time': '2007-2',
#   'price': 22.0,
#   'star': 8.0,
#   'mark_num': 19455}]

# %%
df = pd.DataFrame(list(coll.find({})))
df
# Out:
#                           _id           author        book  mark_num  price  \
# 0    5c3fda8044bb8c3fd8716072      [美] 卡勒德·胡赛尼       追风筝的人    382302   29.0
# 1    5c3fda8044bb8c3fd8716073         [日] 东野圭吾       解忧杂货店    361830   39.5
# 2    5c3fda8044bb8c3fd8716074       [法] 圣埃克苏佩里         小王子    304230   22.0
# 3    5c3fda8044bb8c3fd8716075         [日] 东野圭吾         白夜行    266574   29.8
# 4    5c3fda8044bb8c3fd8716076              钱锺书          围城    233079   19.0
# 5    5c3fda8044bb8c3fd8716077              刘慈欣          三体    215648   23.0
# 6    5c3fda8044bb8c3fd8716078         [日] 东野圭吾     嫌疑人X的献身    213803   28.0
# 7    5c3fda8044bb8c3fd8716079         [日] 村上春树       挪威的森林    222166   18.8
# 8    5c3fda8044bb8c3fd871607a  [哥伦比亚] 加西亚·马尔克斯        百年孤独    165530   39.5
# 9    5c3fda8044bb8c3fd871607b        [清] 曹雪芹 著         红楼梦    157838   59.7
# 10   5c3fda8044bb8c3fd871607c               余华          活着    151704   20.0
# 11   5c3fda8044bb8c3fd871607d               柴静          看见    160894   39.8
# 12   5c3fda8044bb8c3fd871607e      [捷克] 米兰·昆德拉   不能承受的生命之轻    154896   23.0
# 13   5c3fda8044bb8c3fd871607f               路遥  平凡的世界（全三部）    134885   64.0
# 14   5c3fda8044bb8c3fd8716080         [美] 丹·布朗      达·芬奇密码    148828   28.0
# 15   5c3fda8044bb8c3fd8716081              刘慈欣         三体Ⅱ    126385   32.0
# 16   5c3fda8044bb8c3fd8716082              刘慈欣         三体Ⅲ    125878   38.0
# 17   5c3fda8044bb8c3fd8716083      [英] 夏洛蒂·勃朗特    简爱（英文全本）    125815   18.0
# 18   5c3fda8044bb8c3fd8716084               杨绛         我们仨    117606   18.8
# 19   5c3fda8044bb8c3fd8716085               高铭   天才在左 疯子在右    126326   29.8
# 20   5c3fda8044bb8c3fd8716086     [英] J. K. 罗琳   哈利·波特与魔法石    108026   19.5
# 21   5c3fda8044bb8c3fd8716087          [英] 奥斯丁       傲慢与偏见    107648   13.0
# 22   5c3fda8044bb8c3fd8716088             当年明月   明朝那些事儿（壹）    106523   24.8
# 23   5c3fda8044bb8c3fd8716089              龙应台          目送    107156   39.0
# 24   5c3fda8044bb8c3fd871608a    [美国] 玛格丽特·米切尔           飘     95983   40.0
# 25   5c3fda8144bb8c3fd871608b            花城出版社        倾城之恋    104589   11.0
# 26   5c3fda8144bb8c3fd871608c               刘瑜      送你一颗子弹    101628   25.0
# 27   5c3fda8144bb8c3fd871608d         [日] 东野圭吾          恶意    101573   18.0
# 28   5c3fda8144bb8c3fd871608e  [哥伦比亚] 加西亚·马尔克斯     霍乱时期的爱情     94677   39.5
# 29   5c3fda8144bb8c3fd871608f              沈从文          边城     94830   12.0
# ..                        ...              ...         ...       ...    ...
# 220  5c3fda8444bb8c3fd871614e               王朔        动物凶猛     21506   15.5
# 221  5c3fda8444bb8c3fd871614f               三毛       雨季不再来     20249   28.0
# 222  5c3fda8444bb8c3fd8716150               夏达        子不语1     19099   36.0
# 223  5c3fda8444bb8c3fd8716151              严歌苓        小姨多鹤     20349   28.0
# 224  5c3fda8444bb8c3fd8716152     [英] 阿加莎·克里斯蒂        罗杰疑案     19328   21.0
# 225  5c3fda8544bb8c3fd8716153               刘瑜       观念的水位     20960   36.0
# 226  5c3fda8544bb8c3fd8716154               三毛      万水千山走遍     19453   13.8
# 227  5c3fda8544bb8c3fd8716155              杨显惠       夹边沟记事     18410   34.0
# 228  5c3fda8544bb8c3fd8716156              齐邦媛         巨流河     19709   39.0
# 229  5c3fda8544bb8c3fd8716157        [美] 艾·弗洛姆        爱的艺术     19263   15.0
# 230  5c3fda8544bb8c3fd8716158         [英] 莎士比亚        哈姆莱特     20056    7.0
# 231  5c3fda8544bb8c3fd8716159              黄仁宇       中国大历史     20700   19.0
# 232  5c3fda8544bb8c3fd871615a              白先勇         台北人     18926   38.0
# 233  5c3fda8544bb8c3fd871615b         [日] 村上春树       寻羊冒险记     20863   18.8
# 234  5c3fda8544bb8c3fd871615c        （英）乔治·奥威尔        动物庄园     18243   18.0
# 235  5c3fda8544bb8c3fd871615d               林达     带一本书去巴黎     19441   35.0
# 236  5c3fda8544bb8c3fd871615e              王小波        白银时代     19844   10.0
# 237  5c3fda8544bb8c3fd871615f           [英]狄更斯        雾都孤儿     20479   10.1
# 238  5c3fda8544bb8c3fd8716160               桐华        云中歌1     20378   24.8
# 239  5c3fda8544bb8c3fd8716161              湊佳苗          告白     18726  250.0
# 240  5c3fda8544bb8c3fd8716162               海宴         琅琊榜     18588   49.8
# 241  5c3fda8544bb8c3fd8716163      [美] 贾雷德·戴蒙德    枪炮、病菌与钢铁     18397   45.0
# 242  5c3fda8544bb8c3fd8716164             匪我思存     来不及说我爱你     20037   20.0
# 243  5c3fda8544bb8c3fd8716165         [日] 东野圭吾         新参者     19442   28.0
# 244  5c3fda8544bb8c3fd8716166              陈丹青         退步集     19986   38.0
# 245  5c3fda8544bb8c3fd8716167      [美] 米奇·阿尔博姆       相约星期二     19142   19.0
# 246  5c3fda8544bb8c3fd8716168              王小波        红拂夜奔     18550   28.0
# 247  5c3fda8544bb8c3fd8716169               韩寒     可爱的洪水猛兽     19780   25.0
# 248  5c3fda8544bb8c3fd871616a               幾米          星空     17104  369.0
# 249  5c3fda8544bb8c3fd871616b              流潋紫     后宫·甄嬛传Ⅰ     19455   22.0
#
#      star        time
# 0     8.9      2006-5
# 1     8.5      2014-5
# 2     9.0      2003-8
# 3     9.1      2008-9
# 4     8.9      1991-2
# 5     8.8      2008-1
# 6     8.9      2008-9
# 7     8.0      2001-2
# 8     9.2      2011-6
# 9     9.6     1996-12
# 10    9.3    2012-8-1
# 11    8.8    2013-1-1
# 12    8.5      2003-7
# 13    9.0      2005-1
# 14    8.2      2004-2
# 15    9.3      2008-5
# 16    9.2     2010-11
# 17    8.5     2003-11
# 18    8.7      2003-7
# 19    8.2      2010-2
# 20    9.0      2000-9
# 21    8.8      1993-7
# 22    8.7      2006-9
# 23    8.7     2009-10
# 24    9.3      2000-9
# 25    8.5    1997-3-1
# 26    8.6      2010-1
# 27    8.4      2009-6
# 28    9.0    2012-9-1
# 29    8.6      2002-4
# ..    ...         ...
# 220   8.3      2004-2
# 221   8.7      2007-7
# 222   9.0     2009-12
# 223   8.6      2008-4
# 224   8.9      2006-5
# 225   8.3      2013-1
# 226   8.8     2003-08
# 227   9.2     2008-09
# 228   8.7     2010-10
# 229   8.8      2008-4
# 230   8.5      2001-1
# 231   8.3      2007-2
# 232   8.9     2010-10
# 233   8.1      2001-8
# 234   9.1     2000-08
# 235   8.5      2002-5
# 236   8.4      1997-5
# 237   8.1      1991-7
# 238   8.1      2007-9
# 239   8.6  2009年8月31日
# 240   8.5     2007-12
# 241   8.8    2006-4-1
# 242   8.1      2006-9
# 243   8.4      2011-9
# 244   8.1      2005-1
# 245   8.4      2007-7
# 246   8.6      2005-1
# 247   8.1  2009-08-01
# 248   9.0    2009-5-1
# 249   8.0      2007-2
#
# [250 rows x 7 columns]

# %%
data = df.drop('_id', axis=1)

# %%
data['score'] = data['mark_num'] / 10000 * data['star']

# %%
data['score']
# Out:
# 0      340.24878
# 1      307.55550
# 2      273.80700
# 3      242.58234
# 4      207.44031
# 5      189.77024
# 6      190.28467
# 7      177.73280
# 8      152.28760
# 9      151.52448
# 10     141.08472
# 11     141.58672
# 12     131.66160
# 13     121.39650
# 14     122.03896
# 15     117.53805
# 16     115.80776
# 17     106.94275
# 18     102.31722
# 19     103.58732
# 20      97.22340
# 21      94.73024
# 22      92.67501
# 23      93.22572
# 24      89.26419
# 25      88.90065
# 26      87.40008
# 27      85.32132
# 28      85.20930
# 29      81.55380
#          ...
# 220     17.84998
# 221     17.61663
# 222     17.18910
# 223     17.50014
# 224     17.20192
# 225     17.39680
# 226     17.11864
# 227     16.93720
# 228     17.14683
# 229     16.95144
# 230     17.04760
# 231     17.18100
# 232     16.84414
# 233     16.89903
# 234     16.60113
# 235     16.52485
# 236     16.66896
# 237     16.58799
# 238     16.50618
# 239     16.10436
# 240     15.79980
# 241     16.18936
# 242     16.22997
# 243     16.33128
# 244     16.18866
# 245     16.07928
# 246     15.95300
# 247     16.02180
# 248     15.39360
# 249     15.56400
# Name: score, Length: 250, dtype: float64

# %%
data
# Out:
#               author        book  mark_num  price  star        time      score
# 0        [美] 卡勒德·胡赛尼       追风筝的人    382302   29.0   8.9      2006-5  340.24878
# 1           [日] 东野圭吾       解忧杂货店    361830   39.5   8.5      2014-5  307.55550
# 2         [法] 圣埃克苏佩里         小王子    304230   22.0   9.0      2003-8  273.80700
# 3           [日] 东野圭吾         白夜行    266574   29.8   9.1      2008-9  242.58234
# 4                钱锺书          围城    233079   19.0   8.9      1991-2  207.44031
# 5                刘慈欣          三体    215648   23.0   8.8      2008-1  189.77024
# 6           [日] 东野圭吾     嫌疑人X的献身    213803   28.0   8.9      2008-9  190.28467
# 7           [日] 村上春树       挪威的森林    222166   18.8   8.0      2001-2  177.73280
# 8    [哥伦比亚] 加西亚·马尔克斯        百年孤独    165530   39.5   9.2      2011-6  152.28760
# 9          [清] 曹雪芹 著         红楼梦    157838   59.7   9.6     1996-12  151.52448
# 10                余华          活着    151704   20.0   9.3    2012-8-1  141.08472
# 11                柴静          看见    160894   39.8   8.8    2013-1-1  141.58672
# 12       [捷克] 米兰·昆德拉   不能承受的生命之轻    154896   23.0   8.5      2003-7  131.66160
# 13                路遥  平凡的世界（全三部）    134885   64.0   9.0      2005-1  121.39650
# 14          [美] 丹·布朗      达·芬奇密码    148828   28.0   8.2      2004-2  122.03896
# 15               刘慈欣         三体Ⅱ    126385   32.0   9.3      2008-5  117.53805
# 16               刘慈欣         三体Ⅲ    125878   38.0   9.2     2010-11  115.80776
# 17       [英] 夏洛蒂·勃朗特    简爱（英文全本）    125815   18.0   8.5     2003-11  106.94275
# 18                杨绛         我们仨    117606   18.8   8.7      2003-7  102.31722
# 19                高铭   天才在左 疯子在右    126326   29.8   8.2      2010-2  103.58732
# 20      [英] J. K. 罗琳   哈利·波特与魔法石    108026   19.5   9.0      2000-9   97.22340
# 21           [英] 奥斯丁       傲慢与偏见    107648   13.0   8.8      1993-7   94.73024
# 22              当年明月   明朝那些事儿（壹）    106523   24.8   8.7      2006-9   92.67501
# 23               龙应台          目送    107156   39.0   8.7     2009-10   93.22572
# 24     [美国] 玛格丽特·米切尔           飘     95983   40.0   9.3      2000-9   89.26419
# 25             花城出版社        倾城之恋    104589   11.0   8.5    1997-3-1   88.90065
# 26                刘瑜      送你一颗子弹    101628   25.0   8.6      2010-1   87.40008
# 27          [日] 东野圭吾          恶意    101573   18.0   8.4      2009-6   85.32132
# 28   [哥伦比亚] 加西亚·马尔克斯     霍乱时期的爱情     94677   39.5   9.0    2012-9-1   85.20930
# 29               沈从文          边城     94830   12.0   8.6      2002-4   81.55380
# ..               ...         ...       ...    ...   ...         ...        ...
# 220               王朔        动物凶猛     21506   15.5   8.3      2004-2   17.84998
# 221               三毛       雨季不再来     20249   28.0   8.7      2007-7   17.61663
# 222               夏达        子不语1     19099   36.0   9.0     2009-12   17.18910
# 223              严歌苓        小姨多鹤     20349   28.0   8.6      2008-4   17.50014
# 224     [英] 阿加莎·克里斯蒂        罗杰疑案     19328   21.0   8.9      2006-5   17.20192
# 225               刘瑜       观念的水位     20960   36.0   8.3      2013-1   17.39680
# 226               三毛      万水千山走遍     19453   13.8   8.8     2003-08   17.11864
# 227              杨显惠       夹边沟记事     18410   34.0   9.2     2008-09   16.93720
# 228              齐邦媛         巨流河     19709   39.0   8.7     2010-10   17.14683
# 229        [美] 艾·弗洛姆        爱的艺术     19263   15.0   8.8      2008-4   16.95144
# 230         [英] 莎士比亚        哈姆莱特     20056    7.0   8.5      2001-1   17.04760
# 231              黄仁宇       中国大历史     20700   19.0   8.3      2007-2   17.18100
# 232              白先勇         台北人     18926   38.0   8.9     2010-10   16.84414
# 233         [日] 村上春树       寻羊冒险记     20863   18.8   8.1      2001-8   16.89903
# 234        （英）乔治·奥威尔        动物庄园     18243   18.0   9.1     2000-08   16.60113
# 235               林达     带一本书去巴黎     19441   35.0   8.5      2002-5   16.52485
# 236              王小波        白银时代     19844   10.0   8.4      1997-5   16.66896
# 237           [英]狄更斯        雾都孤儿     20479   10.1   8.1      1991-7   16.58799
# 238               桐华        云中歌1     20378   24.8   8.1      2007-9   16.50618
# 239              湊佳苗          告白     18726  250.0   8.6  2009年8月31日   16.10436
# 240               海宴         琅琊榜     18588   49.8   8.5     2007-12   15.79980
# 241      [美] 贾雷德·戴蒙德    枪炮、病菌与钢铁     18397   45.0   8.8    2006-4-1   16.18936
# 242             匪我思存     来不及说我爱你     20037   20.0   8.1      2006-9   16.22997
# 243         [日] 东野圭吾         新参者     19442   28.0   8.4      2011-9   16.33128
# 244              陈丹青         退步集     19986   38.0   8.1      2005-1   16.18866
# 245      [美] 米奇·阿尔博姆       相约星期二     19142   19.0   8.4      2007-7   16.07928
# 246              王小波        红拂夜奔     18550   28.0   8.6      2005-1   15.95300
# 247               韩寒     可爱的洪水猛兽     19780   25.0   8.1  2009-08-01   16.02180
# 248               幾米          星空     17104  369.0   9.0    2009-5-1   15.39360
# 249              流潋紫     后宫·甄嬛传Ⅰ     19455   22.0   8.0      2007-2   15.56400
#
# [250 rows x 7 columns]

# %%
data['price'].mean()
# Out:
# 33.461839999999995

# %%
data['price'].max()
# Out:
# 369.0

# %%
data.describe()
# Out:
#            mark_num       price        star       score
# count     250.00000  250.000000  250.000000  250.000000
# mean    54188.98000   33.461840    8.608000   46.940295
# std     52091.42377   37.844213    0.361967   46.000234
# min     17104.00000    0.000000    8.000000   15.393600
# 25%     25598.00000   19.000000    8.300000   21.362480
# 50%     34460.50000   25.000000    8.600000   29.810960
# 75%     64306.50000   36.000000    8.900000   55.753740
# max    382302.00000  369.000000    9.600000  340.248780

# %%
data.iloc[data['price'].idxmax()]
# Out:
# author            幾米
# book              星空
# mark_num       17104
# price            369
# star               9
# time        2009-5-1
# score        15.3936
# Name: 248, dtype: object

# %%
data.iloc[data['price'].idxmin()]
# Out:
# author              金庸
# book        倚天屠龙记(共四册)
# mark_num         30515
# price                0
# star               8.5
# time           1999-04
# score          25.9377
# Name: 144, dtype: object

# %%
data.sort_values('price').head(10)
# Out:
#        author        book  mark_num  price  star     time     score
# 144        金庸  倚天屠龙记(共四册)     30515   0.00   8.5  1999-04  25.93775
# 129        鲁迅        朝花夕拾     32720   0.25   8.7  1972年4月  28.46640
# 86         鲁迅          呐喊     47953   0.36   8.9  1973年3月  42.67817
# 183     （清）沈复        浮生六记     25295   5.70   8.9   1999/1  22.51255
# 230  [英] 莎士比亚        哈姆莱特     20056   7.00   8.5   2001-1  17.04760
# 131     尾田荣一郎         海贼王     29487   7.50   9.5  2007-11  28.01265
# 52        海明威        老人与海     74487   8.20   8.3  1999-10  61.82421
# 68        小仲马         茶花女     63808   9.00   8.2   1997-3  52.32256
# 72     [英] 笛福      鲁滨逊漂流记     63226   9.20   8.0   2002-1  50.58080
# 156        曹禺          雷雨     29425   9.20   8.6  1999-05  25.30550

# %%
data.sort_values('price', ascending=False).head(10)
# Out:
#         author        book  mark_num  price  star        time     score
# 248         幾米          星空     17104  369.0   9.0    2009-5-1  15.39360
# 108         幾米       月亮忘記了     38336  299.0   8.6    2000-2-1  32.96896
# 239        湊佳苗          告白     18726  250.0   8.6  2009年8月31日  16.10436
# 116       高木直子     一個人住第5年     37027  220.0   8.4   2004-12-1  31.10268
# 30          三毛      撒哈拉的故事     88959  160.0   9.0        1976  80.06310
# 93   [英] 肯·福莱特       巨人的陨落     45655  129.8   8.9    2016-5-1  40.63295
# 134         金庸    鹿鼎记（全五册）     31808  108.0   8.8      2008-3  27.99104
# 191      木心 讲述  文学回忆录（全2册）     22788   98.0   9.2   2013-1-10  20.96496
# 53          金庸        天龙八部     67456   96.0   9.1      1994-5  61.38496
# 76          金庸        神雕侠侣     54001   76.8   8.8      1994-5  47.52088

# %%
data.sort_values('star', ascending=False).head(10)
# Out:
#               author        book  mark_num  price  star       time      score
# 9          [清] 曹雪芹 著         红楼梦    157838   59.7   9.6    1996-12  151.52448
# 131            尾田荣一郎         海贼王     29487    7.5   9.5    2007-11   28.01265
# 164  [美] 乔治·R. R. 马丁   冰与火之歌（卷一）     26013   68.0   9.3     2005-5   24.19209
# 54        [英] 乔治·奥威尔        1984     65807   28.0   9.3   2010-4-1   61.20051
# 24     [美国] 玛格丽特·米切尔           飘     95983   40.0   9.3     2000-9   89.26419
# 147       [英] 乔治·奥威尔   一九八四·动物农场     27501   23.0   9.3     2003-4   25.57593
# 15               刘慈欣         三体Ⅱ    126385   32.0   9.3     2008-5  117.53805
# 10                余华          活着    151704   20.0   9.3   2012-8-1  141.08472
# 191            木心 讲述  文学回忆录（全2册）     22788   98.0   9.2  2013-1-10   20.96496
# 48           [明] 罗贯中   三国演义（全二册）     67875   39.5   9.2    1998-05   62.44500

# %%
data.sort_values('score', ascending=False).head(10)
# Out:
#             author     book  mark_num  price  star     time      score
# 0      [美] 卡勒德·胡赛尼    追风筝的人    382302   29.0   8.9   2006-5  340.24878
# 1         [日] 东野圭吾    解忧杂货店    361830   39.5   8.5   2014-5  307.55550
# 2       [法] 圣埃克苏佩里      小王子    304230   22.0   9.0   2003-8  273.80700
# 3         [日] 东野圭吾      白夜行    266574   29.8   9.1   2008-9  242.58234
# 4              钱锺书       围城    233079   19.0   8.9   1991-2  207.44031
# 6         [日] 东野圭吾  嫌疑人X的献身    213803   28.0   8.9   2008-9  190.28467
# 5              刘慈欣       三体    215648   23.0   8.8   2008-1  189.77024
# 7         [日] 村上春树    挪威的森林    222166   18.8   8.0   2001-2  177.73280
# 8  [哥伦比亚] 加西亚·马尔克斯     百年孤独    165530   39.5   9.2   2011-6  152.28760
# 9        [清] 曹雪芹 著      红楼梦    157838   59.7   9.6  1996-12  151.52448
